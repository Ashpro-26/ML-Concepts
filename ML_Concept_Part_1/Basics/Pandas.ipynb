# %%
import pandas as pd
s = pd.Series([10, 20, 30, 40, 50],name ="Marks")

print(s)
print("Mean value of the series is",s.mean())
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Marks, dtype: int64
# Mean value of the series is 30.0

# %% [markdown]
# **DataFrame(2D Data)**

# %%
data ={
    "Name": ["Alice","Bob","Charlie","David"],
    "Age": [24, 27, 22, 32],
    "Score": [85, 91, 78, 88]
}

data_frame = pd.DataFrame(data)

print(data_frame)
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     91
# 2  Charlie   22     78
# 3    David   32     88

# %%
data_frame.to_csv("data_sample.csv",index= False )

# %% [markdown]
# **Read Data From a CSV File**

# %%
diabetes_df = pd.read_csv("diabetes.csv")
diabetes_df.shape
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
diabetes_df.head()
diabetes_df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df = pd.read_csv("data_sample.csv")
df
# Out:
#       Name  Age  Score
# 0    Alice   24     85
# 1      Bob   27     91
# 2  Charlie   22     78
# 3    David   32     88

# %% [markdown]
# ***Selecting the Data***

# %%
print(df[["Name","Age"]])
print(df.iloc[1])
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   27
# 2  Charlie   22
# 3    David   32
# Name     Bob
# Age       27
# Score     91
# Name: 1, dtype: object

# %%
df["City"] = ["New York","Boston","Toronto","Queens"]
df["Score_Percentage"]= df["Score"]/100 * 100
df
# Out:
#       Name  Age  Score      City  Score_Percentage
# 0    Alice   24     85  New York              85.0
# 1      Bob   27     91    Boston              91.0
# 2  Charlie   22     78   Toronto              78.0
# 3    David   32     88    Queens              88.0

# %% [markdown]
# **Descriptive Statistics**
